# %% [markdown]
# Challenge Data
#
# Import data

# %%
#python -m nltk.downloader all
import pandas as pd, nltk, string

X_train = pd.read_csv("../challenge_dataset/X_train.csv",sep=";").drop(columns='Id')
Y_train = pd.read_csv("../challenge_dataset/y_train.csv",sep=";").drop(columns="Id")
X_test = pd.read_csv("../challenge_dataset/X_test.csv",sep=";").drop(columns='Id ') #space after Id

#X_train
#Y_train
X_test
# Out:
#                                                Caption
# 0               quand tout cela va t il  se terminer ?
# 1    Que le futur demeure incertain... qu'on ne pui...
# 2           De ne plus pouvoir vivre comme auparavant.
# 3                                     pour mes proches
# 4    la honte !!!  d'être un des pays les plus rich...
# ..                                                 ...
# 152  - De rester enfermée,\r\n -  loin des amies ou...
# 153  L'atteinte à nos libertés (appli stop-covi, et...
# 154                                      risque mortel
# 155  ne pas pouvoir sortir\r\n ne pas voir mes peti...
# 156                              la contagion bien sûr
#
# [157 rows x 1 columns]

# %% [markdown]
# Return a list of words from sentences (str)

# %%
def return_token(sentence):
    #print(sentence)
    doc=nltk.word_tokenize(sentence, language='french')
    return [X for X in doc]

# %%
captions_train = [return_token(line) for line in X_train['Caption']]

#print(captions_train)

#for line in X_train['Caption']:
#    print(return_token(line))

# %% [markdown]
# Download or update stopwords from ntlk

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Perlimpinpin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# French stopwords

# %%
from nltk.corpus import stopwords

#print(stopwords.words("french"))

# %%
other_stopwords = ["alors", "au", "aucuns", "aussi", "autre", "avant", "avec", "avoir", "bon", "car", "ce", "cela", "ces", "ceux", "chaque", "ci", "comme", "comment", "dans", "des", "du", "dedans", "dehors", "depuis", "devrait", "doit", "donc", "dos", "début", "elle", "elles", "en", "encore", "essai", "est", "et", "eu", "fait", "faites", "fois", "font", "hors", "ici", "il", "ils", "je", "juste", "la", "le", "les", "leur", "là", "ma", "maintenant", "mais", "mes", "mien", "moins", "mon", "mot", "même", "ni", "nommés", "notre", "nous", "ou", "où", "par", "parce", "pas", "peut", "peu", "plupart", "pour", "pourquoi", "quand", "que", "quel", "quelle", "quelles", "quels", "qui", "sa", "sans", "ses", "seulement", "si", "sien", "son", "sont", "sous", "soyez"    , "sujet", "sur", "ta", "tandis", "tellement", "tels", "tes", "ton", "tous", "tout", "trop", "très", "tu", "voient", "vont", "votre", "vous", "vu", "ça", "étaient", "état", "étions", "été", "être", "l'on"]

allStopwords = [x for x in other_stopwords]
for x in stopwords.words("french"):
    allStopwords.append(x)

#remove duplicates and add punctuation
allStopwords.extend(string.punctuation)
allStopwords.append("...")
allStopwords = list(dict.fromkeys(allStopwords))

#print(allStopwords)

# %% [markdown]
# Filtering

# %%
captions_train_cleaned = []
for message in captions_train:
    captions_train_cleaned.append([word.lower() for word in message if word not in allStopwords])

#print(captions_train_cleaned)

# %% [markdown]
# Stemming, Lemmatization and Part of Speech (POS)

# %% [markdown]
# Stemming, lemmatization and POS Spacy

# %%
#https://maelfabien.github.io/machinelearning/NLPfr/#1-tokenisation

import spacy

# %%
#python3 -m spacy download fr_core_news_md
nlp = spacy.load('fr_core_news_md')

# %%
captions_train_cleaned_stemmed_and_lemmatized_by_spacy = []

for sentence in captions_train_cleaned:
    #nlp on sentences (create sentence back from list of words separated by " ")
    captions_train_cleaned_stemmed_and_lemmatized_by_spacy.append(nlp(' '.join(sentence)))

'''captions_train_cleaned_stemmed_and_lemmatized_by_spacy = [nlp(sentence) for sentence in captions_train_cleaned]

for x in captions_train_cleaned_stemmed_and_lemmatized_by_spacy:
    for token in x:
        print(x,x.lemma_)'''
# Out:
# 'captions_train_cleaned_stemmed_and_lemmatized_by_spacy = [nlp(sentence) for sentence in captions_train_cleaned]\n\nfor x in captions_train_cleaned_stemmed_and_lemmatized_by_spacy:\n    for token in x:\n        print(x,x.lemma_)'

# %%
#Use once

captions_temp = []
POS_captions_train = []
for sentence in captions_train_cleaned_stemmed_and_lemmatized_by_spacy:
    captions_temp.append([token.lemma_ for token in sentence])
    POS_captions_train.append([token.pos_ for token in sentence])
    #for token in sentence:
        #print(token.lemma_,token.pos_)

captions_train_cleaned_stemmed_and_lemmatized_by_spacy=captions_temp
#print(captions_train_cleaned_stemmed_and_lemmatized_by_spacy)

'''
for sentence in captions_train_cleaned_stemmed_and_lemmatized_by_spacy:
    print(sentence)
    for token in sentence:
        print(token,token.lemma_)'''
# Out:
# '\nfor sentence in captions_train_cleaned_stemmed_and_lemmatized_by_spacy:\n    print(sentence)\n    for token in sentence:\n        print(token,token.lemma_)'

# %%
#captions_train_cleaned_stemmed_and_lemmatized_by_spacy
POS_captions_train
# Out:
# [['VERB', 'DET', 'NOUN', 'ADV', 'VERB', 'ADJ', 'NOUN'],
#  ['NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADJ'],
#  ['ADV', 'PRON', 'PRON', 'VERB', 'ADV', 'VERB'],
#  ['NOUN',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN'],
#  ['ADV', 'VERB', 'VERB', 'NOUN'],
#  ['DET', 'NOUN', 'ADJ', 'DET', 'NOUN'],
#  ['ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ'],
#  ['NOUN', 'PROPN'],
#  ['PRON',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'ADP',
#   'NOUN'],
#  ['DET', 'NOUN'],
#  ['NOUN',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'ADV',
#   'ADJ'],
#  ['DET', 'NOUN'],
#  ['NOUN', 'ADJ', 'ADJ', 'CCONJ', 'VERB', 'ADV', 'VERB', 'NOUN', 'ADJ'],
#  ['DET', 'NOUN', 'ADJ', 'NOUN'],
#  ['DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'NOUN'],
#  ['NOUN', 'NOUN', 'ADJ', 'NOUN', 'ADJ'],
#  ['SCONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADJ'],
#  ['ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'DET',
#   'PRON',
#   'PRON',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'PUNCT',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'CCONJ'],
#  ['DET',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'VERB'],
#  ['PRON',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADJ'],
#  ['DET', 'ADV', 'NOUN', 'NOUN', 'VERB'],
#  ['DET',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'AUX',
#   'NOUN',
#   'SYM',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ'],
#  ['NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'ADV',
#   'NOUN',
#   'VERB',
#   'ADJ'],
#  ['NOUN', 'NOUN', 'NOUN', 'ADJ'],
#  ['VERB',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN'],
#  ['NOUN',
#   'ADP',
#   'VERB',
#   'ADJ',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'AUX',
#   'VERB',
#   'ADV',
#   'AUX',
#   'ADJ',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'AUX',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN'],
#  ['NOUN', 'ADJ', 'ADJ', 'ADJ'],
#  ['ADP',
#   'NOUN',
#   'ADV',
#   'AUX',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'NUM',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'ADV',
#   'AUX',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'AUX',
#   'ADV',
#   'VERB',
#   'VERB',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB'],
#  ['PRON',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'PRON',
#   'ADV',
#   'VERB',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'ADP',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'ADP',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'AUX',
#   'X',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN'],
#  ['NOUN',
#   'NOUN',
#   'NUM',
#   'ADJ',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADJ'],
#  ['VERB', 'NOUN', 'ADJ'],
#  ['SCONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB'],
#  ['DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'VERB',
#   'X',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB'],
#  ['NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ'],
#  ['ADP', 'VERB', 'NOUN', 'ADP', 'NOUN'],
#  ['DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'ADJ',
#   'ADV',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'PRON',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN'],
#  ['PRON', 'AUX', 'NOUN', 'ADJ', 'PRON', 'VERB', 'ADP', 'VERB'],
#  ['NOUN', 'NOUN', 'NOUN', 'PRON', 'NOUN', 'ADJ', 'NOUN', 'ADJ'],
#  ['ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN'],
#  ['DET', 'NOUN', 'VERB'],
#  ['AUX', 'VERB', 'VERB', 'NOUN', 'NOUN'],
#  ['VERB',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'SCONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'VERB',
#   'ADJ',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'SCONJ',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'PRON',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'PRON',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB'],
#  ['NOUN', 'ADJ', 'VERB', 'ADJ', 'VERB', 'DET', 'NOUN', 'NOUN'],
#  ['NOUN'],
#  ['ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'AUX',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRON',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN'],
#  ['DET', 'NOUN', 'ADJ'],
#  ['DET',
#   'ADP',
#   'NOUN',
#   'SCONJ',
#   'ADV',
#   'PRON',
#   'PRON',
#   'ADV',
#   'PRON',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'PRON',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'CCONJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'AUX',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'SCONJ',
#   'ADV',
#   'VERB',
#   'PRON',
#   'PRON',
#   'NOUN',
#   'SCONJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADV',
#   'VERB',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP'],
#  ['NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB'],
#  ['SCONJ',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'ADV',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'PUNCT',
#   'SCONJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'PUNCT',
#   'PUNCT',
#   'CCONJ',
#   'ADV',
#   'VERB',
#   'ADJ'],
#  ['SCONJ', 'VERB', 'ADV', 'ADJ', 'NOUN', 'ADJ', 'ADV', 'ADJ'],
#  ['DET', 'NOUN', 'VERB', 'ADV', 'ADV', 'ADJ', 'NOUN'],
#  ['DET', 'NOUN', 'PUNCT', 'NOUN', 'DET', 'NOUN', 'ADJ', 'ADJ'],
#  ['VERB',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PROPN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'PRON',
#   'DET',
#   'PRON',
#   'VERB',
#   'VERB',
#   'NUM'],
#  ['VERB',
#   'VERB',
#   'ADV',
#   'PRON',
#   'VERB',
#   'ADV',
#   'PRON',
#   'VERB',
#   'VERB',
#   'NOUN'],
#  ['DET', 'NOUN', 'VERB', 'ADV'],
#  ['NOUN', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'ADJ', 'PUNCT'],
#  ['PRON', 'NOUN', 'VERB', 'NOUN', 'ADJ'],
#  ['ADJ', 'NOUN', 'ADP', 'AUX', 'ADV'],
#  ['ADJ', 'NOUN', 'DET', 'NOUN', 'ADJ'],
#  ['PRON', 'VERB', 'NOUN', 'ADJ'],
#  ['DET',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'PRON',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP'],
#  ['ADP', 'DET', 'NOUN', 'ADJ', 'ADP', 'ADJ', 'NOUN', 'ADV', 'ADJ'],
#  ['NOUN', 'VERB', 'NOUN', 'ADV', 'VERB', 'NOUN', 'VERB', 'CCONJ'],
#  ['VERB', 'ADP'],
#  ['ADV', 'ADJ', 'ADJ', 'NOUN', 'NOUN'],
#  ['NOUN',
#   'AUX',
#   'VERB',
#   'ADJ',
#   'VERB',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'PUNCT'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'SCONJ',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB'],
#  ['AUX',
#   'VERB',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'VERB'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADV'],
#  ['AUX', 'VERB'],
#  ['NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN'],
#  ['AUX',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'PRON',
#   'AUX',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'PRON',
#   'AUX',
#   'ADJ',
#   'ADP',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADV',
#   'ADP'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'ADJ'],
#  ['ADV',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PROPN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'ADV',
#   'NUM',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'PUNCT'],
#  ['PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB'],
#  ['SCONJ', 'NOUN', 'ADJ'],
#  ['NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', 'ADV', 'VERB'],
#  ['ADV', 'DET', 'NOUN', 'ADJ', 'PRON', 'VERB', 'NOUN', 'NOUN'],
#  ['DET', 'NOUN', 'ADP', 'VERB', 'NOUN', 'ADV', 'VERB', 'DET', 'NOUN', 'ADJ'],
#  ['PRON',
#   'ADJ',
#   'PRON',
#   'ADV',
#   'AUX',
#   'NOUN',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN'],
#  ['PROPN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NOUN'],
#  ['SCONJ',
#   'PRON',
#   'AUX',
#   'VERB',
#   'PROPN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'PRON',
#   'DET',
#   'NOUN',
#   'ADJ'],
#  ['DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'AUX',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NUM',
#   'VERB',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADV',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP'],
#  ['SCONJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'PROPN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NOUN'],
#  ['DET',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'AUX',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN'],
#  ['NOUN', 'ADJ'],
#  ['NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'AUX',
#   'VERB',
#   'NOUN',
#   'ADJ'],
#  ['VERB',
#   'ADV',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'AUX',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'PRON',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'NOUN'],
#  [],
#  ['ADV',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN'],
#  ['VERB',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'ADJ',
#   'NOUN'],
#  ['DET', 'NOUN', 'ADV', 'ADJ', 'NOUN', 'NOUN'],
#  ['NOUN', 'ADJ', 'ADJ'],
#  ['DET', 'NOUN', 'NOUN', 'PRON', 'PRON', 'VERB', 'NOUN'],
#  ['NOUN', 'ADV', 'NOUN', 'NOUN'],
#  ['VERB', 'NOUN', 'VERB', 'DET', 'NOUN'],
#  ['NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ'],
#  ['DET',
#   'NOUN',
#   'ADV',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'AUX',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'PROPN',
#   'PROPN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN'],
#  ['DET',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN'],
#  ['VERB', 'NOUN'],
#  ['NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN'],
#  ['ADV', 'VERB', 'NOUN', 'VERB', 'NOUN', 'ADJ', 'PROPN', 'VERB', 'ADV', 'ADV'],
#  ['VERB', 'NOUN', 'ADJ', 'NOUN', 'NUM', 'NOUN'],
#  ['DET',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN'],
#  ['ADP',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'PRON',
#   'PRON',
#   'PRON',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ'],
#  ['PRON',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ'],
#  ['PROPN'],
#  ['VERB',
#   'NUM',
#   'NOUN',
#   'PRON',
#   'AUX',
#   'VERB',
#   'NOUN',
#   'AUX',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN'],
#  ['NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NUM',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'VERB',
#   'VERB',
#   'PROPN',
#   'NOUN',
#   'PRON',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'PRON',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ'],
#  ['ADV',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'PUNCT',
#   'ADP',
#   'AUX',
#   'PRON',
#   'ADJ'],
#  ['ADV', 'ADJ', 'NOUN', 'ADJ', 'NOUN', 'ADV', 'VERB', 'NOUN'],
#  ['NOUN',
#   'ADV',
#   'NUM',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'SCONJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB'],
#  ['ADJ'],
#  ['DET',
#   'PRON',
#   'AUX',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'PRON',
#   'VERB',
#   'NOUN'],
#  ['DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADJ', 'DET', 'NOUN', 'ADJ'],
#  ['NOUN'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'ADV',
#   'NOUN',
#   'PROPN',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'NOUN'],
#  ['ADV', 'ADV', 'VERB', 'ADJ', 'DET', 'NOUN', 'NOUN', 'ADJ'],
#  ['ADV',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'AUX',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'SYM',
#   'ADJ'],
#  ['DET', 'NOUN', 'DET', 'NOUN', 'ADP', 'NOUN'],
#  ['NOUN', 'NOUN', 'ADJ', 'ADJ', 'DET', 'NOUN', 'NOUN'],
#  ['NOUN', 'NOUN', 'ADJ', 'VERB'],
#  ['DET',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'DET',
#   'ADJ',
#   'VERB',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN'],
#  ['VERB', 'NOUN', 'NOUN', 'ADJ', 'ADJ'],
#  ['VERB', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'NUM'],
#  ['PRON',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADV'],
#  ['NOUN', 'ADV', 'ADJ', 'NOUN', 'ADJ', 'ADJ', 'ADV', 'VERB', 'ADV', 'NOUN'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'VERB'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'AUX',
#   'NOUN',
#   'PRON',
#   'AUX',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'NUM',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'AUX',
#   'VERB',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NOUN'],
#  ['AUX', 'ADV', 'ADJ', 'NOUN', 'NOUN'],
#  ['PRON',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'AUX',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADJ'],
#  ['VERB', 'NOUN'],
#  ['AUX', 'ADJ', 'VERB', 'NOUN', 'ADV', 'ADJ', 'ADJ'],
#  ['PRON',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'X',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN'],
#  ['DET', 'NOUN', 'NOUN', 'NOUN', 'VERB'],
#  ['DET', 'NOUN', 'ADJ', 'NOUN'],
#  ['DET', 'NOUN', 'NOUN', 'DET', 'ADJ', 'NOUN', 'VERB', 'PRON'],
#  ['DET', 'NOUN', 'NOUN', 'ADP', 'NOUN'],
#  ['SCONJ', 'DET', 'NOUN', 'ADJ', 'ADV', 'NOUN'],
#  ['AUX',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PROPN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN'],
#  ['NOUN', 'NOUN'],
#  ['DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'SCONJ',
#   'DET',
#   'NOUN',
#   'PROPN',
#   'ADJ',
#   'VERB',
#   'DET',
#   'PROPN',
#   'X',
#   'VERB',
#   'NOUN',
#   'ADP'],
#  ['DET', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'ADJ'],
#  ['NOUN',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADV',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN'],
#  ['NOUN', 'VERB', 'NOUN', 'ADJ'],
#  ['NOUN', 'ADV', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'ADJ', 'NOUN', 'NOUN'],
#  ['VERB', 'NOUN', 'NOUN', 'PRON', 'VERB', 'PUNCT'],
#  ['AUX',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'VERB',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'PRON',
#   'AUX',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ'],
#  ['VERB', 'NOUN', 'ADJ', 'NOUN', 'VERB'],
#  ['PRON', 'NOUN', 'ADP', 'ADP', 'VERB', 'NOUN', 'ADP', 'ADP'],
#  ['SCONJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'PUNCT'],
#  ['VERB',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'ADV',
#   'VERB',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP'],
#  ['DET', 'NOUN', 'NOUN', 'ADP', 'ADP', 'ADJ', 'NOUN'],
#  ['ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'VERB'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'VERB'],
#  ['NOUN',
#   'ADP',
#   'AUX',
#   'ADJ',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'PROPN'],
#  ['AUX', 'VERB', 'VERB', 'NOUN'],
#  ['DET', 'NOUN', 'ADJ'],
#  ['ADJ',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PROPN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'PRON'],
#  ['PRON',
#   'PROPN',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'PUNCT',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   'VERB',
#   'PUNCT',
#   'ADJ',
#   'PUNCT',
#   'SCONJ',
#   'VERB',
#   'NOUN',
#   'CCONJ',
#   'ADP',
#   'ADV',
#   'ADV',
#   'SCONJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'VERB',
#   'ADV',
#   'AUX',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN'],
#  ['NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'AUX',
#   'ADV',
#   'ADJ'],
#  ['DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NUM',
#   'VERB',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'NOUN'],
#  ['VERB', 'NOUN', 'ADJ', 'ADP', 'NOUN', 'NOUN'],
#  ['VERB', 'VERB', 'VERB', 'ADV'],
#  ['DET', 'NOUN', 'PRON', 'PRON', 'VERB', 'ADV', 'NOUN', 'ADJ'],
#  ['NOUN',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'AUX',
#   'DET',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'AUX',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ'],
#  ['ADP',
#   'PRON',
#   'AUX',
#   'ADJ',
#   'NOUN',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADJ'],
#  ['NOUN', 'NOUN', 'ADJ', 'DET', 'ADP', 'NOUN'],
#  ['DET',
#   'PRON',
#   'PRON',
#   'ADJ',
#   'PRON',
#   'PRON',
#   'PRON',
#   'PRON',
#   'AUX',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'ADJ'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'AUX',
#   'VERB',
#   'CCONJ',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'AUX',
#   'VERB',
#   'ADV',
#   'ADJ'],
#  ['NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ'],
#  ['DET', 'NOUN', 'ADJ', 'DET', 'NOUN', 'NOUN', 'NOUN', 'VERB'],
#  ['NOUN', 'VERB', 'ADJ'],
#  ['SCONJ', 'NOUN', 'ADJ', 'PRON', 'AUX', 'NOUN', 'ADJ', 'ADJ', 'NOUN'],
#  ['PRON',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ'],
#  ['ADP', 'NOUN', 'ADP', 'NOUN', 'VERB', 'NOUN', 'ADJ'],
#  ['ADP',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'PROPN',
#   'ADV',
#   'NUM',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ'],
#  ['NUM',
#   'NOUN',
#   'SCONJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'X',
#   'ADJ',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'SCONJ',
#   'ADJ',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NUM',
#   'NOUN',
#   'SCONJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN'],
#  ['ADV',
#   'AUX',
#   'ADV',
#   'ADJ',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN'],
#  ['NOUN',
#   'ADJ',
#   'ADV',
#   'ADV',
#   'SCONJ',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'VERB',
#   'ADV'],
#  ['ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'AUX',
#   'VERB',
#   'ADP',
#   'AUX',
#   'VERB',
#   'ADP',
#   'AUX',
#   'VERB',
#   'ADV',
#   'PUNCT',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADJ'],
#  ['NOUN', 'VERB', 'ADJ', 'NOUN', 'VERB', 'ADJ'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN'],
#  ['DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADJ', 'ADJ'],
#  ['DET', 'VERB', 'NOUN', 'ADV'],
#  ['PRON',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'AUX',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADJ'],
#  ['ADJ',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN'],
#  ['ADP', 'VERB', 'VERB', 'NOUN', 'VERB', 'NOUN', 'ADJ', 'NOUN'],
#  ['PRON',
#   'ADV',
#   'AUX',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRON',
#   'PRON',
#   'PRON',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'ADV',
#   'AUX',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'VERB'],
#  ['NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ'],
#  ['NOUN', 'NOUN', 'VERB', 'VERB', 'NOUN'],
#  ['ADV', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', 'ADJ'],
#  ['ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN'],
#  ['NOUN', 'ADJ', 'NOUN', 'PUNCT'],
#  ['NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADP',
#   'VERB',
#   'PUNCT'],
#  ['NOUN', 'ADP', 'DET', 'NOUN'],
#  ['VERB', 'NOUN', 'ADJ', 'VERB', 'NOUN', 'ADJ'],
#  ['DET'],
#  ['NOUN',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'SCONJ',
#   'ADJ'],
#  ['DET', 'NOUN', 'PUNCT', 'NOUN', 'ADJ'],
#  ['DET', 'NOUN', 'DET', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'ADJ', 'ADJ'],
#  ['VERB', 'NOUN', 'ADJ', 'NOUN'],
#  ['NOUN', 'DET', 'NOUN', 'NOUN', 'ADV', 'ADJ', 'NOUN'],
#  ['DET', 'ADJ', 'NOUN', 'DET', 'NOUN', 'NOUN', 'ADJ'],
#  ['NOUN', 'ADJ'],
#  ['NOUN', 'ADJ'],
#  ['VERB', 'ADJ'],
#  ['VERB', 'ADJ', 'ADJ', 'VERB', 'ADJ'],
#  ['NOUN', 'ADJ', 'ADJ', 'ADV', 'ADJ'],
#  ['NOUN', 'NOUN', 'NOUN', 'NOUN', 'ADJ', 'ADJ', 'NOUN'],
#  ['AUX', 'ADJ', 'AUX', 'VERB'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'PROPN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'ADJ',
#   'VERB'],
#  ['NOUN', 'ADV', 'NOUN', 'ADJ'],
#  ['DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'PROPN',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'PUNCT'],
#  ['DET', 'NOUN', 'DET', 'NOUN', 'NOUN', 'NOUN', 'ADJ', 'NOUN', 'ADJ', 'PUNCT'],
#  ['PRON', 'VERB', 'DET', 'NOUN', 'VERB', 'PRON', 'VERB'],
#  ['DET', 'NOUN', 'PRON', 'AUX', 'VERB', 'NOUN', 'ADP', 'VERB', 'DET', 'NOUN'],
#  ['PRON',
#   'AUX',
#   'ADV',
#   'VERB',
#   'ADV',
#   'ADV',
#   'AUX',
#   'ADJ',
#   'VERB',
#   'ADJ',
#   'ADV',
#   'ADV',
#   'ADP',
#   'ADV',
#   'NOUN'],
#  ['NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ'],
#  ['SCONJ',
#   'PRON',
#   'ADV',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'ADJ'],
#  ['VERB',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'PUNCT'],
#  ['SCONJ', 'PRON', 'ADP', 'ADJ', 'NOUN', 'NOUN'],
#  ['NOUN'],
#  ['NOUN', 'ADP', 'DET', 'NOUN', 'ADV', 'NOUN', 'NOUN', 'ADJ'],
#  ['SCONJ', 'NOUN', 'VERB', 'NOUN', 'ADV', 'ADP', 'ADV', 'VERB'],
#  ['ADV',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'NOUN'],
#  ['NOUN', 'ADP', 'ADJ', 'NOUN'],
#  ['ADP',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADJ'],
#  ['AUX',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'ADV',
#   'VERB'],
#  ['NOUN',
#   'ADV',
#   'VERB',
#   'ADV',
#   'ADV',
#   'VERB',
#   'ADV',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'ADJ'],
#  ['ADV',
#   'ADV',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN'],
#  ['ADV', 'ADJ', 'ADJ', 'VERB', 'NUM', 'NOUN', 'VERB', 'ADJ', 'NOUN'],
#  ['DET', 'NOUN', 'ADP', 'NOUN'],
#  ['DET', 'NOUN', 'NOUN', 'DET', 'NOUN'],
#  ['NOUN'],
#  ['NUM',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NUM',
#   'X',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN'],
#  ['NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ'],
#  ['NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADV',
#   'NOUN',
#   'ADV',
#   'AUX',
#   'X',
#   'X'],
#  [],
#  ['AUX', 'ADJ', 'AUX', 'VERB'],
#  ['DET', 'NOUN', 'ADP', 'VERB', 'DET', 'NOUN'],
#  ['NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'VERB'],
#  ['ADJ',
#   'ADV',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PROPN',
#   'ADJ',
#   'ADJ'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'CCONJ',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ'],
#  ['AUX', 'VERB', 'NOUN'],
#  ['ADJ', 'NOUN', 'NUM', 'NOUN', 'ADJ', 'NOUN', 'NUM', 'NOUN'],
#  ['DET',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB'],
#  ['ADJ', 'ADJ', 'VERB'],
#  ['VERB', 'ADJ', 'VERB', 'NOUN', 'ADJ', 'NOUN', 'NOUN', 'NOUN'],
#  ['SCONJ', 'NOUN', 'VERB'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'VERB',
#   'PUNCT',
#   'DET',
#   'NOUN'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN'],
#  ['DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'ADJ'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN'],
#  ['NOUN', 'ADJ', 'NOUN', 'NOUN', 'ADJ', 'ADJ'],
#  ['ADV',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'ADJ',
#   'NOUN'],
#  ['PRON', 'VERB', 'DET', 'NOUN', 'ADJ', 'ADV'],
#  ['ADJ', 'ADV', 'ADV', 'ADV', 'ADJ', 'ADP', 'DET', 'ADJ', 'NOUN'],
#  ['ADV', 'ADJ', 'NOUN'],
#  ['ADV',
#   'ADV',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADJ'],
#  ['ADP', 'NOUN', 'ADV', 'ADJ'],
#  ['VERB', 'ADJ'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   'AUX',
#   'ADV',
#   'DET',
#   'NOUN',
#   'PROPN',
#   'X',
#   'VERB',
#   'PUNCT',
#   'VERB',
#   'NOUN'],
#  ['DET',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'VERB'],
#  ['PRON', 'ADJ', 'VERB', 'NOUN', 'VERB', 'ADJ', 'VERB', 'ADV'],
#  ['NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'AUX',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'PROPN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN'],
#  ['ADV', 'ADJ', 'ADJ'],
#  ['PRON', 'VERB', 'VERB', 'NOUN', 'NOUN', 'AUX', 'NOUN', 'ADP', 'NOUN'],
#  ['VERB',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NUM',
#   'NOUN'],
#  ['VERB', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'PRON'],
#  ['NOUN', 'DET', 'NOUN'],
#  ['PRON',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN'],
#  ['NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN'],
#  ['NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'X',
#   'AUX',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PROPN',
#   'X',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADJ'],
#  ['PRON',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'AUX',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'SCONJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ'],
#  ['NOUN',
#   'AUX',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'PROPN',
#   'NOUN',
#   'PROPN'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'PROPN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  ['NOUN',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN'],
#  ['AUX',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADV',
#   'NOUN',
#   'AUX',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'NOUN',
#   'ADV',
#   'AUX',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'AUX',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'AUX',
#   'PRON',
#   'ADJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADV'],
#  ['ADP', 'PRON', 'VERB'],
#  ['VERB',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   'ADV',
#   'ADV',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP'],
#  ['AUX',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADV',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'ADJ',
#   'ADV',
#   'AUX',
#   'VERB',
#   'PRON',
#   'AUX',
#   'PRON',
#   'ADJ',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'PROPN'],
#  ['DET', 'NOUN', 'NOUN'],
#  ['NOUN', 'ADJ', 'ADJ', 'NOUN', 'ADJ'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN'],
#  ['ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'PROPN',
#   'CCONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'ADJ',
#   'ADV',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADJ',
#   'ADV',
#   'ADJ'],
#  ['DET', 'NOUN', 'DET', 'NOUN', 'NOUN'],
#  ['ADP',
#   'AUX',
#   'VERB',
#   'ADP',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'AUX'],
#  ['DET', 'NOUN', 'VERB', 'ADV', 'NOUN', 'NOUN', 'VERB', 'PRON', 'VERB'],
#  ['VERB', 'NOUN', 'ADJ', 'ADJ', 'PRON', 'VERB', 'ADV'],
#  ['VERB', 'VERB', 'NOUN', 'ADV'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'X',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADJ'],
#  ['NOUN', 'NOUN', 'ADV', 'ADJ', 'NOUN', 'ADJ'],
#  ['NOUN', 'NOUN', 'ADJ', 'NOUN', 'DET'],
#  ['VERB',
#   'NOUN',
#   'SCONJ',
#   'PRON',
#   'AUX',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'AUX',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN'],
#  ['NOUN', 'ADJ', 'ADJ'],
#  ['ADV',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'PRON',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN'],
#  ['ADV', 'NOUN', 'ADJ', 'NOUN', 'NOUN'],
#  ['ADV', 'VERB', 'NOUN', 'NOUN', 'AUX', 'ADJ'],
#  ['ADP', 'VERB', 'ADJ', 'ADP', 'ADJ', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADV'],
#  ['NUM',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NUM',
#   'SCONJ',
#   'VERB',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'VERB',
#   'VERB',
#   'PRON',
#   'VERB',
#   'DET',
#   'AUX',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'PRON',
#   'PRON',
#   'NOUN',
#   'PRON',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'NOUN'],
#  ['NOUN', 'NOUN', 'NOUN', 'ADJ', 'NOUN', 'ADJ', 'NOUN'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'CCONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   'PRON',
#   'AUX',
#   'ADJ',
#   'CCONJ',
#   'PRON',
#   'AUX',
#   'NOUN'],
#  ['NOUN',
#   'ADV',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ'],
#  ['NOUN', 'ADJ', 'ADJ', 'NOUN', 'NUM', 'ADJ', 'NOUN', 'NOUN', 'ADJ', 'VERB'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'PRON',
#   'PRON',
#   'VERB',
#   'VERB',
#   'AUX',
#   'PRON',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'NOUN'],
#  ['NOUN', 'ADV', 'VERB', 'ADJ', 'NOUN', 'NOUN', 'VERB', 'ADJ', 'VERB', 'NOUN'],
#  ['NOUN', 'ADJ'],
#  ['ADP',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NUM',
#   'VERB',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'VERB'],
#  ['PRON', 'VERB', 'NOUN', 'ADP', 'NOUN', 'ADJ'],
#  ['NOUN', 'NUM', 'ADV', 'AUX', 'NOUN', 'DET', 'NOUN', 'ADJ'],
#  ['DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN'],
#  ['NOUN', 'ADJ', 'ADV', 'DET', 'PRON', 'NOUN', 'ADJ', 'ADJ', 'VERB'],
#  ['NOUN', 'ADJ'],
#  ['VERB'],
#  ['NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'X',
#   'AUX',
#   'ADV',
#   'ADV'],
#  ['NOUN',
#   'ADP',
#   'AUX',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADV',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'DET',
#   'NOUN'],
#  ['ADV', 'ADV', 'ADJ', 'ADV', 'NOUN', 'NOUN'],
#  ['NOUN', 'ADJ', 'VERB', 'VERB'],
#  ['PRON', 'ADV', 'AUX', 'ADV', 'ADJ', 'SCONJ', 'PRON', 'VERB'],
#  ['NOUN', 'ADJ', 'ADJ', 'PUNCT', 'NOUN'],
#  ['ADV',
#   'ADP',
#   'NOUN',
#   'DET',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'SCONJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'PROPN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ'],
#  ['NUM',
#   'SCONJ',
#   'ADJ',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'NUM',
#   'PRON',
#   'PRON',
#   'ADV',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'NUM',
#   'SCONJ',
#   'NOUN',
#   'NOUN',
#   'VERB'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'PROPN'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   'AUX',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN'],
#  ['ADV', 'VERB', 'ADJ', 'NOUN'],
#  ['NOUN'],
#  ['NOUN', 'NOUN', 'ADJ', 'NOUN'],
#  ['NOUN',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADV',
#   'SCONJ',
#   'PRON',
#   'NOUN',
#   'ADJ',
#   'NOUN'],
#  ['DET', 'NOUN', 'VERB', 'NOUN', 'ADJ', 'ADJ', 'ADJ', 'ADJ'],
#  ['DET', 'NOUN', 'ADJ', 'NOUN', 'NOUN', 'ADJ', 'AUX', 'VERB'],
#  ['NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'AUX',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'DET',
#   'NOUN'],
#  ['DET', 'NOUN', 'PRON', 'NOUN', 'VERB', 'NOUN', 'ADJ'],
#  ['NOUN', 'ADJ'],
#  ['ADV',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADV',
#   'SCONJ',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'PUNCT'],
#  ['ADP', 'ADV', 'ADJ', 'NOUN', 'ADJ'],
#  ['DET'],
#  ['ADP',
#   'ADV',
#   'ADV',
#   'ADP',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'AUX',
#   'NOUN',
#   'VERB',
#   'CCONJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADP'],
#  ['VERB',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ'],
#  ['NOUN', 'VERB', 'ADJ'],
#  ['ADV', 'ADV', 'VERB', 'VERB'],
#  ['ADJ'],
#  ['VERB', 'VERB', 'ADJ', 'ADV', 'ADJ', 'DET', 'ADJ', 'VERB', 'NOUN', 'ADP'],
#  ['AUX',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'AUX',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN'],
#  ['NOUN', 'DET', 'NOUN', 'ADV', 'ADJ'],
#  ['NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'VERB'],
#  ['ADP', 'NOUN', 'NOUN', 'VERB', 'ADJ', 'PRON', 'VERB', 'NOUN'],
#  ['NOUN',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN'],
#  ['NOUN', 'ADP', 'NOUN', 'VERB', 'NOUN', 'NOUN'],
#  ['NOUN',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ'],
#  ['DET',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN'],
#  ['PRON',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'ADV',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'PROPN',
#   'AUX',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'ADP',
#   'PUNCT',
#   'NOUN',
#   'NOUN'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'AUX',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['PROPN',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'ADJ',
#   'ADV',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN'],
#  ['NUM',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'PROPN',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'PROPN',
#   'AUX',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'ADJ'],
#  ['ADP',
#   'AUX',
#   'NOUN',
#   'PRON',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'AUX',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'ADJ'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['DET', 'NOUN', 'ADJ', 'ADV', 'NOUN', 'NOUN', 'ADJ'],
#  ['NOUN', 'NOUN', 'NOUN', 'NOUN', 'ADJ'],
#  ['SCONJ', 'NOUN', 'PRON', 'NOUN', 'ADV', 'NOUN'],
#  ['VERB',
#   'ADP',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'AUX',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'PRON',
#   'AUX',
#   'ADJ'],
#  ['ADV',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'AUX',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'ADP',
#   'ADP'],
#  ['NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ'],
#  ['ADV', 'NOUN', 'VERB', 'AUX', 'VERB'],
#  ['NOUN', 'ADJ', 'ADJ', 'ADJ'],
#  ['PRON', 'ADJ', 'PRON', 'VERB', 'ADV', 'ADV'],
#  ['NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'PROPN'],
#  ['NOUN', 'ADJ'],
#  ['NUM',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'VERB',
#   'NOUN'],
#  ['VERB', 'NOUN'],
#  ['ADV',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   'ADV',
#   'VERB',
#   'PRON',
#   'VERB',
#   'NOUN'],
#  ['NOUN', 'ADJ', 'ADJ', 'NOUN', 'NOUN', 'NOUN'],
#  ['ADV', 'VERB', 'VERB', 'NOUN', 'ADJ', 'NOUN', 'PRON', 'AUX', 'VERB', 'NOUN'],
#  ['DET',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'VERB',
#   'VERB',
#   'SCONJ',
#   'PRON',
#   'NOUN',
#   'CCONJ',
#   'SYM',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['ADV',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ'],
#  ['DET', 'NOUN', 'ADP', 'AUX', 'NOUN', 'ADJ', 'ADJ', 'ADJ', 'NOUN'],
#  ['DET', 'VERB', 'NOUN'],
#  ['NOUN', 'NOUN', 'NOUN', 'NOUN', 'ADJ', 'NOUN', 'NOUN'],
#  ['ADV', 'PUNCT'],
#  ['AUX', 'ADV', 'ADJ', 'X'],
#  ['NOUN', 'ADJ', 'VERB', 'VERB', 'VERB', 'NOUN'],
#  ['VERB', 'PRON', 'VERB'],
#  ['NOUN',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ'],
#  ['SCONJ', 'DET', 'NOUN', 'VERB', 'ADV', 'VERB', 'NOUN', 'VERB', 'ADV'],
#  ['NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'ADJ'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADJ'],
#  ['DET', 'VERB', 'VERB', 'NOUN', 'ADJ', 'PUNCT'],
#  ['DET',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'ADJ',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ'],
#  ['NOUN', 'NOUN', 'PUNCT', 'NOUN'],
#  ['DET',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN'],
#  ['ADV', 'NOUN', 'NOUN', 'ADJ'],
#  ['DET',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ'],
#  ['ADV', 'AUX', 'NOUN', 'ADJ', 'NOUN', 'VERB', 'NOUN', 'ADJ', 'NOUN'],
#  ['ADP', 'VERB', 'ADJ', 'NOUN', 'CCONJ', 'VERB', 'VERB', 'NOUN'],
#  ['ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'PRON',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'AUX',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'PUNCT',
#   'ADP'],
#  ['DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'ADP',
#   'ADV',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'ADV',
#   'ADV',
#   'NOUN'],
#  ['ADV',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN'],
#  ['NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'DET',
#   'ADJ',
#   'NOUN'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADJ'],
#  ['DET', 'NOUN', 'ADJ', 'NOUN', 'ADJ', 'ADJ', 'NOUN'],
#  ['SCONJ', 'NOUN', 'ADJ', 'PRON', 'VERB', 'VERB', 'ADJ', 'VERB'],
#  ['PRON', 'VERB'],
#  ['DET'],
#  ['NUM', 'NOUN', 'ADJ', 'NOUN', 'ADJ', 'VERB'],
#  ['ADJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'NUM',
#   'PRON',
#   'VERB',
#   'VERB',
#   'PROPN',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'NOUN'],
#  ['NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN'],
#  ['ADV',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN'],
#  ['VERB',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN'],
#  ['NOUN', 'ADJ'],
#  ['NOUN', 'ADP', 'AUX', 'VERB', 'VERB', 'ADP'],
#  ['AUX', 'VERB', 'ADJ', 'ADJ'],
#  ['NOUN', 'NOUN', 'ADJ', 'ADJ', 'PROPN', 'NOUN'],
#  ['NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'VERB',
#   'PRON',
#   'AUX',
#   'ADJ'],
#  ['ADV',
#   'VERB',
#   'VERB',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADJ'],
#  ['VERB', 'NOUN', 'NOUN'],
#  ['DET', 'NOUN', 'ADV', 'ADJ', 'ADJ'],
#  ['DET', 'ADJ', 'NOUN', 'NOUN', 'VERB'],
#  ['ADJ', 'NOUN', 'VERB', 'ADJ'],
#  ['VERB',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'PRON',
#   'VERB',
#   'PRON',
#   'PROPN',
#   'DET',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'AUX',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'VERB',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN'],
#  ['ADV', 'NOUN'],
#  ['NOUN', 'ADJ', 'ADJ', 'ADJ', 'ADV', 'NOUN'],
#  ['DET', 'NOUN', 'ADJ', 'DET', 'NOUN', 'ADJ', 'DET', 'NOUN', 'ADJ'],
#  ['VERB', 'VERB'],
#  ['NOUN', 'ADJ', 'ADJ'],
#  ['DET',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'DET',
#   'PROPN',
#   'PROPN'],
#  ['VERB', 'NOUN', 'CCONJ', 'VERB', 'NOUN', 'NOUN'],
#  ['ADV',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'SCONJ',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   'AUX',
#   'PRON',
#   'SCONJ',
#   'ADP',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'VERB'],
#  ['PRON', 'VERB', 'ADJ'],
#  ['NOUN', 'ADP', 'ADV'],
#  ['NOUN', 'ADJ'],
#  ['VERB',
#   'ADJ',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'ADJ'],
#  ['NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'X',
#   'ADV',
#   'ADV',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP'],
#  ['NOUN', 'ADJ'],
#  ['NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'AUX',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN'],
#  ['ADP', 'VERB', 'VERB', 'ADV'],
#  ['NOUN',
#   'ADJ',
#   'PROPN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ'],
#  ['VERB',
#   'PRON',
#   'VERB',
#   'NUM',
#   'DET',
#   'NOUN',
#   'PRON',
#   'AUX',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'AUX',
#   'VERB',
#   'ADJ'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'NOUN'],
#  ['NOUN',
#   'ADP',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'ADV',
#   'PROPN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'PROPN',
#   'ADJ',
#   'ADJ'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'AUX',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'PRON',
#   'ADV',
#   'VERB',
#   'ADJ',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ'],
#  ['DET',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN'],
#  ['DET', 'NOUN', 'VERB', 'ADJ', 'NOUN', 'VERB'],
#  ['ADV', 'ADJ', 'VERB', 'NOUN', 'ADJ', 'PRON', 'VERB', 'ADV'],
#  ['NOUN', 'ADJ', 'NOUN'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN'],
#  ['NOUN',
#   'ADV',
#   'ADJ',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'PRON',
#   'NOUN'],
#  ['DET', 'NOUN'],
#  ['NOUN', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADV', 'NOUN', 'ADJ', 'ADJ'],
#  ['VERB', 'NOUN', 'VERB', 'NOUN', 'NOUN'],
#  ['NOUN', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADV', 'NOUN', 'ADJ', 'ADJ'],
#  ['NOUN', 'ADV', 'NOUN', 'ADV'],
#  ['NOUN', 'ADJ', 'VERB', 'NOUN'],
#  ['SCONJ', 'DET', 'NOUN', 'VERB', 'ADV', 'SCONJ', 'PRON', 'VERB', 'ADV'],
#  ['DET', 'NOUN', 'PUNCT', 'SCONJ', 'PROPN'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'AUX',
#   'VERB',
#   'VERB',
#   'ADV',
#   'AUX',
#   'DET',
#   'NOUN'],
#  ['NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'AUX',
#   'VERB'],
#  ['ADJ', 'DET', 'NOUN', 'VERB', 'NOUN'],
#  ['NOUN', 'NOUN', 'ADJ'],
#  ['NOUN', 'VERB', 'ADJ'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB'],
#  ['VERB',
#   'VERB',
#   'PROPN',
#   'ADJ',
#   'ADP',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADJ'],
#  ['ADP', 'NOUN', 'ADJ', 'DET', 'NOUN', 'NOUN', 'ADJ', 'NOUN', 'ADJ', 'ADJ'],
#  ['NOUN', 'ADJ', 'VERB'],
#  ['VERB', 'NOUN', 'NOUN', 'ADJ', 'DET', 'ADP', 'NOUN', 'PROPN', 'NOUN', 'ADJ'],
#  ['ADP',
#   'PRON',
#   'VERB',
#   'CCONJ',
#   'ADP',
#   'AUX',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN'],
#  ['PRON', 'PRON', 'VERB', 'ADV', 'DET', 'NOUN', 'PRON', 'ADV', 'ADJ'],
#  ['DET', 'NOUN', 'ADJ', 'ADJ', 'NOUN'],
#  ['ADJ'],
#  ['VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN'],
#  ['NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'VERB'],
#  ['DET', 'NOUN', 'ADJ', 'ADJ', 'ADV', 'PRON', 'DET', 'NOUN', 'ADJ', 'NOUN'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN'],
#  ['NOUN', 'ADJ', 'PROPN'],
#  ['NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'AUX',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'ADP'],
#  ['DET',
#   'NOUN',
#   'PRON',
#   'ADV',
#   'ADV',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ'],
#  ['NOUN', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'ADJ', 'NOUN', 'ADJ'],
#  ['SCONJ', 'ADJ', 'VERB', 'NOUN']]

# %% [markdown]
# Function returning the cleaned, stemmed and lemmatized set and the list of POS

# %%
#https://maelfabien.github.io/machinelearning/NLPfr/#1-tokenisation

import pandas as pd, nltk, string, spacy
from nltk.corpus import stopwords

#python -m nltk.downloader all
nltk.download("stopwords")

def return_token(sentence):
    #print(sentence)
    doc=nltk.word_tokenize(sentence, language='french')
    return [X for X in doc]


def treat_data(input_data):
    other_stopwords = ["alors", "au", "aucuns", "aussi", "autre", "avant", "avec", "avoir", "bon", "car", "ce", "cela", "ces", "ceux", "chaque", "ci", "comme", "comment", "dans", "des", "du", "dedans", "dehors", "depuis", "devrait", "doit", "donc", "dos", "début", "elle", "elles", "en", "encore", "essai", "est", "et", "eu", "fait", "faites", "fois", "font", "hors", "ici", "il", "ils", "je", "juste", "la", "le", "les", "leur", "là", "ma", "maintenant", "mais", "mes", "mien", "moins", "mon", "mot", "même", "ni", "nommés", "notre", "nous", "ou", "où", "par", "parce", "pas", "peut", "peu", "plupart", "pour", "pourquoi", "quand", "que", "quel", "quelle", "quelles", "quels", "qui", "sa", "sans", "ses", "seulement", "si", "sien", "son", "sont", "sous", "soyez"    , "sujet", "sur", "ta", "tandis", "tellement", "tels", "tes", "ton", "tous", "tout", "trop", "très", "tu", "voient", "vont", "votre", "vous", "vu", "ça", "étaient", "état", "étions", "été", "être", "l'on"]

    allStopwords = [x for x in other_stopwords]
    for x in stopwords.words("french"):
        allStopwords.append(x)

    #remove duplicates and add punctuation
    allStopwords.extend(string.punctuation)
    allStopwords.append("...")
    allStopwords = list(dict.fromkeys(allStopwords))
    
    
    captions_train = [return_token(line) for line in input_data['Caption']]
    
    captions_train_cleaned = []
    for message in captions_train:
        captions_train_cleaned.append([word.lower() for word in message if word not in allStopwords])
    
    #python3 -m spacy download fr_core_news_md
    nlp = spacy.load('fr_core_news_md')
    
    captions_train_cleaned_stemmed_and_lemmatized_by_spacy = []

    for sentence in captions_train_cleaned:
        #nlp on sentences (create sentence back from list of words separated by " ")
        captions_train_cleaned_stemmed_and_lemmatized_by_spacy.append(nlp(' '.join(sentence)))
    
    captions_temp = []
    POS_captions_train = []
    for sentence in captions_train_cleaned_stemmed_and_lemmatized_by_spacy:
        captions_temp.append([token.lemma_ for token in sentence])
        POS_captions_train.append([token.pos_ for token in sentence])
    
    captions_train_cleaned_stemmed_and_lemmatized_by_spacy=captions_temp
    
    return captions_train_cleaned_stemmed_and_lemmatized_by_spacy,POS_captions_train
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Perlimpinpin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
