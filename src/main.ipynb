# %% [markdown]
# Challenge Data
#
# Import data

# %%
import pandas as pd, nltk, string

X_train = pd.read_csv("../challenge_dataset/X_train.csv",sep=";").drop(columns='Id')
Y_train = pd.read_csv("../challenge_dataset/y_train.csv",sep=";").drop(columns="Id")
X_test = pd.read_csv("../challenge_dataset/X_test.csv",sep=";").drop(columns='Id ') #space after Id

#X_train
#Y_train
X_test
# Out:
#                                                Caption
# 0               quand tout cela va t il  se terminer ?
# 1    Que le futur demeure incertain... qu'on ne pui...
# 2           De ne plus pouvoir vivre comme auparavant.
# 3                                     pour mes proches
# 4    la honte !!!  d'être un des pays les plus rich...
# ..                                                 ...
# 152  - De rester enfermée,\r\n -  loin des amies ou...
# 153  L'atteinte à nos libertés (appli stop-covi, et...
# 154                                      risque mortel
# 155  ne pas pouvoir sortir\r\n ne pas voir mes peti...
# 156                              la contagion bien sûr
#
# [157 rows x 1 columns]

# %% [markdown]
# Return a list of words from sentences (str)

# %%
def return_token(sentence):
    #print(sentence)
    doc=nltk.word_tokenize(sentence, language='french')
    return [X for X in doc]

# %%
captions_train = [return_token(line) for line in X_train['Caption']]

print(captions_train)

#for line in X_train['Caption']:
#    print(return_token(line))
# Out:
# [['de', 'mourir', 'avant', "l'heure", 'de', 'ne', 'plus', 'revoir', 'mes', 'petits', 'enfants'], ['la', 'maladie', 'pour', 'les', 'autres', 'et', 'pour', 'moi', 'et', 'les', 'conséquences', 'sur', 'la', 'jeune', 'génération', 'qui', 'vit', 'une', 'situation', 'tout', 'à', 'fait', 'insolite', ':', "l'arrêt", 'de', 'toute', 'vie', 'sociale', 'et', 'active'], ['Comment', 'vont', "s'en", 'sortir', 'ceux', 'qui', 'sont', 'mal', 'ou', 'pas', 'du', 'tout', 'logées', '?'], ['Inquiétude', 'pour', 'la', 'santé', 'de', 'mes', 'proches', ',', 'pour', 'les', 'plus', 'fragiles', '(', 'femmes', 'battues', ',', 'enfants', 'en', 'danger', ',', 'prisonniers', ',', 'sdf', ')', ',', 'pour', 'la', 'crise', 'économique', 'avérée', 'et', 'une', 'possible', 'crise', 'sociale', 'par', 'la', 'suite', '.'], ['Bien', 'entendu', 'contracter', 'la', 'maladie', ','], ['La', 'multiplication', 'des', 'pandémies', 'pour', "l'avenir"], ['de', 'nombreuses', 'reprises', 'de', 'la', 'pandémie', 'au', 'cours', 'des', 'prochaines', 'années', 'une', 'fermeture', 'des', 'pays', 'et', 'une', 'crise', 'économique', 'qui', 'touche', 'une', 'énorme', 'partie', 'de', 'la', 'population', 'mondiale'], ['Effondrement', 'de', 'l', 'economir'], ['Je', 'crains', 'une', 'modification', 'de', 'la', 'nature', 'des', 'relations', 'entre', 'les', 'personnes', '(', 'vers', 'plus', "d'égoïsmes", ')', '.'], ["L'incivilité"], ['la', 'reprise', 'en', 'plusieurs', 'étapes', 'de', 'la', 'pandémie', 'la', 'crise', 'économique', 'et', 'sociale', ',', 'en', 'particulier', 'chez', 'les', 'plus', 'd', '&', 'munis'], ['La', 'reanimation'], ['que', 'ma', 'famille', 'soit', 'touchée', 'par', 'ce', 'microbe', 'Mais', 'moi', 'je', 'veux', 'bien', 'mourir', 'à', 'la', 'place', 'des', 'jeunes'], ['La', 'sortie', 'prudente', ',', 'sans', 'trop', 'de', 'dégâts'], ["l'aspect", 'gravissime', 'de', 'la', 'maladie', 'chez', 'certains', 'patients', 'et', 'notamment', 'chez', 'les', 'personnes', 'âgées.La', 'perspective', "d'une", 'mort', 'très', 'pénible', 'par', 'étouffement', "L'absence", "d'un", 'vaccin', 'pour', 'encore', 'de', 'nombreux', 'mois', 'Des', 'conditions', 'de', 'vie', 'très', 'entravées', 'par', 'le', 'phénomène', 'de', 'contamination', 'ce', 'qui', 'entraine', 'un', 'isolement', 'supportable', 'un', 'moment', ',', 'mais', 'qui', 'finirait', 'par', 'avoir', 'de', 'graves', 'répercussions', 'psychologiques', ',', 'dans', 'toutes', 'les', 'catégories', 'sociales.Plus', 'graves', 'certainement', 'pour', 'le', 'grand', 'âge', '.'], ['Contagion', ',', 'crise', 'sociétale', ',', 'crise', 'economique'], ['Que', 'cette', 'crise', 'ne', 'nous', 'fasse', 'pas', 'suffisamment', 'prendre', 'conscience', 'des', 'excès', 'de', 'notre', 'société', 'Crise', 'économique', 'grave', 'avec', 'toutes', 'ses', 'conséquence', 'sociales'], ['Sans', 'doute', 'le', 'comportement', "d'une", 'partie', '(', 'une', 'partie', 'seulement', '....', 'mais', 'assez', 'importante', 'à', 'mes', 'yeux', '!', '...', ')', 'de', 'nos', "'compatriotes", "'", ':', 'la', 'critique', 'systématique', ',', "l'individualisme", ',', "l'orgueil", ',', "l'Ego", '...', "m'inquiètent", 'ils', 'plus', 'que', 'la', 'maladie', 'elle', 'même', '....', 'Bien', 'entendu', ',', 'sur', 'la', 'balance', ',', 'il', 'y', 'a', 'toutes', 'les', 'belles', 'attitudes', '...', 'Mais', '...'], ['Une', 'pandémie', 'longue', ',', 'difficilement', 'maîtrisable', 'et', 'pour', 'laquelle', 'les', 'mesures', 'proposées', 'par', 'les', 'scientifiques', 'dans', 'le', 'monde', 'sont', 'trop', 'différentes', 'ce', 'qui', 'laisse', 'planer', 'un', 'doute', 'sur', 'leur', 'efficacitées', '.'], ['Cela', 'peut', 'être', 'un', 'danger', 'grave', 'pour', 'les', 'plus', 'fragiles', 'tant', 'que', 'les', 'moyens', 'ne', 'seront', 'pas', 'mis', 'en', 'oeuvre', 'pour', "l'éradiquer", '(', 'test', ',', 'masques', ')'], ['Le', 'non', 'respect', 'des', 'mesures', 'réclamées'], ["L'inconscience", 'de', 'beaucoup', 'de', 'citoyens', 'la', 'difficulté', 'de', 'protéger', 'la', 'populati ...

# %% [markdown]
# Download or update stopwords from ntlk

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Perlimpinpin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# French stopwords

# %%
from nltk.corpus import stopwords

#print(stopwords.words("french"))

# %%
other_stopwords = ["alors", "au", "aucuns", "aussi", "autre", "avant", "avec", "avoir", "bon", "car", "ce", "cela", "ces", "ceux", "chaque", "ci", "comme", "comment", "dans", "des", "du", "dedans", "dehors", "depuis", "devrait", "doit", "donc", "dos", "début", "elle", "elles", "en", "encore", "essai", "est", "et", "eu", "fait", "faites", "fois", "font", "hors", "ici", "il", "ils", "je", "juste", "la", "le", "les", "leur", "là", "ma", "maintenant", "mais", "mes", "mien", "moins", "mon", "mot", "même", "ni", "nommés", "notre", "nous", "ou", "où", "par", "parce", "pas", "peut", "peu", "plupart", "pour", "pourquoi", "quand", "que", "quel", "quelle", "quelles", "quels", "qui", "sa", "sans", "ses", "seulement", "si", "sien", "son", "sont", "sous", "soyez"    , "sujet", "sur", "ta", "tandis", "tellement", "tels", "tes", "ton", "tous", "tout", "trop", "très", "tu", "voient", "vont", "votre", "vous", "vu", "ça", "étaient", "état", "étions", "été", "être", "l'on"]

allStopwords = [x for x in other_stopwords]
for x in stopwords.words("french"):
    allStopwords.append(x)

#remove duplicates and add punctuation
allStopwords.extend(string.punctuation)
allStopwords.append("...")
allStopwords = list(dict.fromkeys(allStopwords))

print(allStopwords)
# Out:
# ['alors', 'au', 'aucuns', 'aussi', 'autre', 'avant', 'avec', 'avoir', 'bon', 'car', 'ce', 'cela', 'ces', 'ceux', 'chaque', 'ci', 'comme', 'comment', 'dans', 'des', 'du', 'dedans', 'dehors', 'depuis', 'devrait', 'doit', 'donc', 'dos', 'début', 'elle', 'elles', 'en', 'encore', 'essai', 'est', 'et', 'eu', 'fait', 'faites', 'fois', 'font', 'hors', 'ici', 'il', 'ils', 'je', 'juste', 'la', 'le', 'les', 'leur', 'là', 'ma', 'maintenant', 'mais', 'mes', 'mien', 'moins', 'mon', 'mot', 'même', 'ni', 'nommés', 'notre', 'nous', 'ou', 'où', 'par', 'parce', 'pas', 'peut', 'peu', 'plupart', 'pour', 'pourquoi', 'quand', 'que', 'quel', 'quelle', 'quelles', 'quels', 'qui', 'sa', 'sans', 'ses', 'seulement', 'si', 'sien', 'son', 'sont', 'sous', 'soyez', 'sujet', 'sur', 'ta', 'tandis', 'tellement', 'tels', 'tes', 'ton', 'tous', 'tout', 'trop', 'très', 'tu', 'voient', 'vont', 'votre', 'vous', 'vu', 'ça', 'étaient', 'état', 'étions', 'été', 'être', "l'on", 'aux', 'de', 'eux', 'lui', 'me', 'moi', 'ne', 'nos', 'on', 'qu', 'se', 'te', 'toi', 'un', 'une', 'vos', 'c', 'd', 'j', 'l', 'à', 'm', 'n', 's', 't', 'y', 'étée', 'étées', 'étés', 'étant', 'étante', 'étants', 'étantes', 'suis', 'es', 'sommes', 'êtes', 'serai', 'seras', 'sera', 'serons', 'serez', 'seront', 'serais', 'serait', 'serions', 'seriez', 'seraient', 'étais', 'était', 'étiez', 'fus', 'fut', 'fûmes', 'fûtes', 'furent', 'sois', 'soit', 'soyons', 'soient', 'fusse', 'fusses', 'fût', 'fussions', 'fussiez', 'fussent', 'ayant', 'ayante', 'ayantes', 'ayants', 'eue', 'eues', 'eus', 'ai', 'as', 'avons', 'avez', 'ont', 'aurai', 'auras', 'aura', 'aurons', 'aurez', 'auront', 'aurais', 'aurait', 'aurions', 'auriez', 'auraient', 'avais', 'avait', 'avions', 'aviez', 'avaient', 'eut', 'eûmes', 'eûtes', 'eurent', 'aie', 'aies', 'ait', 'ayons', 'ayez', 'aient', 'eusse', 'eusses', 'eût', 'eussions', 'eussiez', 'eussent', '!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~', '...']

# %% [markdown]
# Filtering

# %%
captions_train_cleaned = []
for message in captions_train:
    captions_train_cleaned.append([word.lower() for word in message if word not in allStopwords])

print(captions_train_cleaned)
# Out:
# [['mourir', "l'heure", 'plus', 'revoir', 'petits', 'enfants'], ['maladie', 'autres', 'conséquences', 'jeune', 'génération', 'vit', 'situation', 'insolite', "l'arrêt", 'toute', 'vie', 'sociale', 'active'], ['comment', "s'en", 'sortir', 'mal', 'logées'], ['inquiétude', 'santé', 'proches', 'plus', 'fragiles', 'femmes', 'battues', 'enfants', 'danger', 'prisonniers', 'sdf', 'crise', 'économique', 'avérée', 'possible', 'crise', 'sociale', 'suite'], ['bien', 'entendu', 'contracter', 'maladie'], ['la', 'multiplication', 'pandémies', "l'avenir"], ['nombreuses', 'reprises', 'pandémie', 'cours', 'prochaines', 'années', 'fermeture', 'pays', 'crise', 'économique', 'touche', 'énorme', 'partie', 'population', 'mondiale'], ['effondrement', 'economir'], ['je', 'crains', 'modification', 'nature', 'relations', 'entre', 'personnes', 'vers', 'plus', "d'égoïsmes"], ["l'incivilité"], ['reprise', 'plusieurs', 'étapes', 'pandémie', 'crise', 'économique', 'sociale', 'particulier', 'chez', 'plus', 'munis'], ['la', 'reanimation'], ['famille', 'touchée', 'microbe', 'mais', 'veux', 'bien', 'mourir', 'place', 'jeunes'], ['la', 'sortie', 'prudente', 'dégâts'], ["l'aspect", 'gravissime', 'maladie', 'chez', 'certains', 'patients', 'notamment', 'chez', 'personnes', 'âgées.la', 'perspective', "d'une", 'mort', 'pénible', 'étouffement', "l'absence", "d'un", 'vaccin', 'nombreux', 'mois', 'des', 'conditions', 'vie', 'entravées', 'phénomène', 'contamination', 'entraine', 'isolement', 'supportable', 'moment', 'finirait', 'graves', 'répercussions', 'psychologiques', 'toutes', 'catégories', 'sociales.plus', 'graves', 'certainement', 'grand', 'âge'], ['contagion', 'crise', 'sociétale', 'crise', 'economique'], ['que', 'cette', 'crise', 'fasse', 'suffisamment', 'prendre', 'conscience', 'excès', 'société', 'crise', 'économique', 'grave', 'toutes', 'conséquence', 'sociales'], ['sans', 'doute', 'comportement', "d'une", 'partie', 'partie', '....', 'assez', 'importante', 'yeux', "'compatriotes", 'critique', 'systématique', "l'individualisme", "l'orgueil", "l'ego", "m'inquiètent", 'plus', 'maladie', '....', 'bien', 'entendu', 'balance', 'a', 'toutes', 'belles', 'attitudes', 'mais'], ['une', 'pandémie', 'longue', 'difficilement', 'maîtrisable', 'laquelle', 'mesures', 'proposées', 'scientifiques', 'monde', 'différentes', 'laisse', 'planer', 'doute', 'efficacitées'], ['cela', 'danger', 'grave', 'plus', 'fragiles', 'tant', 'moyens', 'mis', 'oeuvre', "l'éradiquer", 'test', 'masques'], ['le', 'non', 'respect', 'mesures', 'réclamées'], ["l'inconscience", 'beaucoup', 'citoyens', 'difficulté', 'protéger', 'population', 'lieux', 'publics', 'ecoles/', 'supermarchés/et', 'lieux', 'loisirs', 'restaurants', 'cinémas', 'musées'], ['adaptation', 'cette', 'vie', 'portant', 'masques', 'partiellement', 'privée', 'liberté', 'promener', 'nez', "'air", 'revoir', 'visu', 'gens', 'aimés', 'plus', 'âgés', 'non', 'violence', 'délinquance', 'grandissante'], ['peur', 'parents', 'amis', 'malades'], ['manque', 'connaisance', "l'évolution", 'nouveau', 'virus-', 'manque', 'traitement', 'apaisant', 'crise', 'manque', "d'équipements", 'protection', "d'assistance"], ['peur', "d'avoir", 'microbe', "qu'on", 'sait', 'dangereux', 'plus', 'âges', 'porteurs', 'plus', "d'autres", 'pathologies', "l'impression", "d'être", 'pestiférés', "n'avoir", 'possibilités', 'voir', 'plus', 'petits', 'personne', 'rencontrée', 'suspecte', "d'être", 'dangereuse', "d'issue", 'visible', 'cette', 'crise'], ['difficultes', 'sanitaires', 'sociales', 'politiques'], ['comme', 'jour', "n'est", 'connu', 'aucun', 'vaccin', 'peut-être', 'an', 'deux', 'dit-on', 'tests', "n'ont", 'commencé', 'déconfinement', '11/05/2020', 'masques', 'conformes', 'public', 'disponibles', 'navigue', 'brouillard', "d'autant", 'plus', 'mauvaise', 'gestion', 'gouvernement', 'français', 'cette', 'épidémie', 'comme', 'gouvernement', 'a', 'beaucoup', 'menti', 'a', 'quoi', 'sceptique', 'gestion', 'prochaines', 'semaines', 'mois', 'venir'], ['je', 'volontairement', 'confiné', ...

# %% [markdown]
# Stemming and Lemmatization

# %% [markdown]
# Stemming NLTK

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Perlimpinpin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#French stemmer
from nltk.stem import SnowballStemmer

# %%
stemmer = SnowballStemmer(language="french")

captions_train_cleaned_stemmed = []
for message in captions_train_cleaned:
    captions_train_cleaned_stemmed.append([stemmer.stem(word) for word in message])

print(captions_train_cleaned_stemmed)
# Out:
# [['mour', "l'heur", 'plus', 'revoir', 'petit', 'enfant'], ['malad', 'autr', 'conséquent', 'jeun', 'géner', 'vit', 'situat', 'insolit', "l'arrêt", 'tout', 'vi', 'social', 'activ'], ['comment', "s'en", 'sort', 'mal', 'log'], ['inquiétud', 'sant', 'proch', 'plus', 'fragil', 'femm', 'battu', 'enfant', 'dang', 'prisonni', 'sdf', 'cris', 'économ', 'aver', 'possibl', 'cris', 'social', 'suit'], ['bien', 'entendu', 'contract', 'malad'], ['la', 'multipl', 'pandem', "l'aven"], ['nombreux', 'repris', 'pandem', 'cour', 'prochain', 'anné', 'fermetur', 'pay', 'cris', 'économ', 'touch', 'énorm', 'part', 'popul', 'mondial'], ['effondr', 'econom'], ['je', 'crain', 'modif', 'natur', 'relat', 'entre', 'person', 'ver', 'plus', "d'égoïsm"], ["l'incivil"], ['repris', 'plusieur', 'étap', 'pandem', 'cris', 'économ', 'social', 'particuli', 'chez', 'plus', 'mun'], ['la', 'reanim'], ['famill', 'touch', 'microb', 'mais', 'veux', 'bien', 'mour', 'plac', 'jeun'], ['la', 'sort', 'prudent', 'dégât'], ["l'aspect", 'gravissim', 'malad', 'chez', 'certain', 'patient', 'not', 'chez', 'person', 'âgées.l', 'perspect', "d'un", 'mort', 'pénibl', 'étouff', "l'absenc", "d'un", 'vaccin', 'nombreux', 'mois', 'de', 'condit', 'vi', 'entrav', 'phénomen', 'contamin', 'entrain', 'isol', 'support', 'moment', 'fin', 'grav', 'répercuss', 'psycholog', 'tout', 'catégor', 'sociales.plus', 'grav', 'certain', 'grand', 'âge'], ['contagion', 'cris', 'sociétal', 'cris', 'econom'], ['que', 'cet', 'cris', 'fass', 'suffis', 'prendr', 'conscienc', 'exces', 'societ', 'cris', 'économ', 'grav', 'tout', 'conséquent', 'social'], ['san', 'dout', 'comport', "d'un", 'part', 'part', '....', 'assez', 'import', 'yeux', "'compatriot", 'critiqu', 'systémat', "l'individual", "l'orgueil", "l'ego", "m'inquiètent", 'plus', 'malad', '....', 'bien', 'entendu', 'balanc', 'a', 'tout', 'bel', 'attitud', 'mais'], ['une', 'pandem', 'longu', 'difficil', 'maîtris', 'laquel', 'mesur', 'propos', 'scientif', 'mond', 'différent', 'laiss', 'plan', 'dout', 'efficacit'], ['cel', 'dang', 'grav', 'plus', 'fragil', 'tant', 'moyen', 'mis', 'oeuvr', "l'éradiqu", 'test', 'masqu'], ['le', 'non', 'respect', 'mesur', 'réclam'], ["l'inconscient", 'beaucoup', 'citoyen', 'difficult', 'proteg', 'popul', 'lieux', 'public', 'ecoles/', 'supermarchés/et', 'lieux', 'loisir', 'restaur', 'cinem', 'mus'], ['adapt', 'cet', 'vi', 'port', 'masqu', 'partiel', 'priv', 'libert', 'promen', 'nez', "'air", 'revoir', 'visu', 'gen', 'aim', 'plus', 'âgé', 'non', 'violenc', 'délinqu', 'grand'], ['peur', 'parent', 'amis', 'malad'], ['manqu', 'connais', "l'évolu", 'nouveau', 'virus-', 'manqu', 'trait', 'apais', 'cris', 'manqu', "d'équip", 'protect', "d'assist"], ['peur', "d'avoir", 'microb', "qu'on", 'sait', 'danger', 'plus', 'âge', 'porteur', 'plus', "d'autr", 'patholog', "l'impress", "d'êtr", 'pestifer', "n'avoir", 'possibil', 'voir', 'plus', 'petit', 'person', 'rencontr', 'suspect', "d'êtr", 'danger', "d'issu", 'visibl', 'cet', 'cris'], ['difficult', 'sanitair', 'social', 'polit'], ['comm', 'jour', "n'est", 'connu', 'aucun', 'vaccin', 'peut-êtr', 'an', 'deux', 'dit-on', 'test', "n'ont", 'commenc', 'déconfin', '11/05/2020', 'masqu', 'conform', 'public', 'disponibl', 'navigu', 'brouillard', "d'aut", 'plus', 'mauvais', 'gestion', 'gouvern', 'franc', 'cet', 'épidem', 'comm', 'gouvern', 'a', 'beaucoup', 'ment', 'a', 'quoi', 'sceptiqu', 'gestion', 'prochain', 'semain', 'mois', 'ven'], ['je', 'volontair', 'confin', 'mer', '98', 'an', "j'en", '71', 'afin', 'mettr', "'hor", 'circuit', 'concierg', 'femm', 'ménag', 'etc.', "jusqu'ic", 'port', 'assist', 'minimis', 'risqu', 'contamin', 'me', 'consider', "'en", 'form', 'crain', 'grand', 'chos', 'person', 'cel', 'épous', 'a', 'fortior', 'fil', 'compagn', "l'âg", 'vieil', 'maman', 'rend', 'fragil', 'verr'], ['-notr', 'sant', '-té', 'personnel', '-nos', 'rapport', 'familial', '-nos', 'rapport', 'social', "-l'économ", 'pay', '-le', 'tension', 'social', '-un', 'cris', 'financi'], ['attrap', 'chos', 'grav'], ['que', "l'occas" ...

# %% [markdown]
# Lemmatization Spacy

# %%
#https://maelfabien.github.io/machinelearning/NLPfr/#1-tokenisation

import spacy

# %%
#python3 -m spacy download fr_core_news_md
nlp = spacy.load('fr_core_news_md')

# %%
captions_train_cleaned_stemmed_and_lemmatized_by_spacy = []

for sentence in captions_train_cleaned:
    #nlp on sentences (create sentence back from list of words separated by " ")
    captions_train_cleaned_stemmed_and_lemmatized_by_spacy.append(nlp(' '.join(sentence)))

'''captions_train_cleaned_stemmed_and_lemmatized_by_spacy = [nlp(sentence) for sentence in captions_train_cleaned]

for x in captions_train_cleaned_stemmed_and_lemmatized_by_spacy:
    for token in x:
        print(x,x.lemma_)'''
# Out:
# 'captions_train_cleaned_stemmed_and_lemmatized_by_spacy = [nlp(sentence) for sentence in captions_train_cleaned]\n\nfor x in captions_train_cleaned_stemmed_and_lemmatized_by_spacy:\n    for token in x:\n        print(x,x.lemma_)'

# %%
captions_temp = []
for sentence in captions_train_cleaned_stemmed_and_lemmatized_by_spacy:
    captions_temp.append([token.lemma_ for token in sentence])

captions_train_cleaned_stemmed_and_lemmatized_by_spacy=captions_temp
print(captions_train_cleaned_stemmed_and_lemmatized_by_spacy)

'''
for sentence in captions_train_cleaned_stemmed_and_lemmatized_by_spacy:
    print(sentence)
    for token in sentence:
        print(token,token.lemma_)'''
# Out:
# [['mourir', 'le', 'heure', 'plus', 'revoir', 'petit', 'enfant'], ['maladie', 'autre', 'conséquence', 'jeune', 'génération', 'voir', 'situation', 'insolite', 'le', 'arrêt', 'tout', 'vie', 'social', 'actif'], ['comment', 'se', 'en', 'sortir', 'mal', 'loger'], ['inquiétude', 'santé', 'proche', 'plus', 'fragile', 'femme', 'battre', 'enfant', 'danger', 'prisonnier', 'sdf', 'crise', 'économique', 'avérer', 'possible', 'crise', 'social', 'suite'], ['bien', 'entendre', 'contracter', 'maladie'], ['le', 'multiplication', 'pandémie', 'le', 'avenir'], ['nombreux', 'reprise', 'pandémie', 'cours', 'prochain', 'année', 'fermeture', 'pays', 'crise', 'économique', 'touche', 'énorme', 'partie', 'population', 'mondial'], ['effondrement', 'economir'], ['je', 'craindre', 'modification', 'nature', 'relation', 'entrer', 'personne', 'vers', 'plus', 'de', 'égoïsme'], ['le', 'incivilité'], ['reprise', 'plusieurs', 'étape', 'pandémie', 'crise', 'économique', 'social', 'particulier', 'chez', 'plus', 'munir'], ['le', 'reanimation'], ['famille', 'toucher', 'microb', 'mais', 'vouloir', 'bien', 'mourir', 'place', 'jeune'], ['le', 'sortie', 'prudent', 'dégât'], ['le', 'aspect', 'gravissime', 'maladie', 'chez', 'certain', 'patient', 'notamment', 'chez', 'personne', 'âgées.la', 'perspective', 'de', 'un', 'mort', 'pénible', 'étouffement', 'le', 'absence', 'de', 'un', 'vaccin', 'nombreux', 'mois', 'de', 'condition', 'vie', 'entraver', 'phénomène', 'contamination', 'entraine', 'isolement', 'supportable', 'moment', 'finir', 'grave', 'répercussion', 'psychologique', 'tout', 'catégorie', 'sociales.plus', 'grave', 'certainement', 'grand', 'âge'], ['contagion', 'crise', 'sociétal', 'crise', 'economiqu'], ['que', 'ce', 'crise', 'faire', 'suffisamment', 'prendre', 'conscience', 'excès', 'société', 'crise', 'économique', 'grave', 'tout', 'conséquence', 'social'], ['sans', 'doute', 'comportement', 'de', 'un', 'partie', 'partie', '....', 'assez', 'important', 'oeil', "'", 'compatriote', 'critique', 'systématique', 'le', 'individualisme', 'le', 'orgueil', 'le', 'ego', 'me', 'inquiéter', 'plus', 'maladie', '....', 'bien', 'entendre', 'balance', 'avoir', 'tout', 'bel', 'attitude', 'mais'], ['un', 'pandémie', 'long', 'difficilement', 'maîtrisable', 'lequel', 'mesure', 'proposer', 'scientifique', 'monde', 'différent', 'laisse', 'planer', 'doute', 'efficaciter'], ['celer', 'danger', 'grave', 'plus', 'fragile', 'tant', 'moyen', 'mettre', 'oeuvre', 'le', 'éradiquer', 'test', 'masque'], ['le', 'non', 'respect', 'mesure', 'réclamer'], ['le', 'inconscience', 'beaucoup', 'citoyen', 'difficulté', 'protéger', 'population', 'lieu', 'public', 'ecoles/', 'supermarché', '/', 'et', 'lieu', 'loisir', 'restaurant', 'cinéma', 'musée'], ['adaptation', 'ce', 'vie', 'porter', 'masque', 'partiellement', 'priver', 'liberté', 'promener', 'nez', "'", 'air', 'revoir', 'visu', 'gens', 'aimer', 'plus', 'âgé', 'non', 'violence', 'délinquance', 'grandissant'], ['peur', 'parent', 'ami', 'malade'], ['manque', 'connaisance', 'le', 'évolution', 'nouveau', 'virus-', 'manque', 'traitement', 'apaisant', 'crise', 'manque', 'de', 'équipement', 'protection', 'de', 'assistance'], ['peur', 'de', 'avoir', 'microb', 'que', 'on', 'savoir', 'dangereux', 'plus', 'âge', 'porteur', 'plus', 'de', 'autre', 'pathologie', 'le', 'impression', 'de', 'être', 'pestiférer', 'ne', 'avoir', 'possibilité', 'voir', 'plus', 'petit', 'personne', 'rencontrer', 'suspect', 'de', 'être', 'dangereux', 'de', 'issue', 'visible', 'ce', 'crise'], ['difficulte', 'sanitaire', 'social', 'politique'], ['comme', 'jour', 'ne', 'être', 'connaître', 'aucun', 'vaccin', 'peut-être', 'an', 'deux', 'dire', 'on', 'test', 'ne', 'avoir', 'commencer', 'déconfinement', '11/05/2020', 'masque', 'conforme', 'public', 'disponible', 'naviguer', 'brouillard', 'de', 'autant', 'plus', 'mauvais', 'gestion', 'gouvernement', 'français', 'ce', 'épidémie', 'comme', 'gouvernement', 'avoir', 'beaucoup', 'mentir', 'avoir', 'quoi', 'sceptique', 'gestion', 'prochain', 'semaine', 'moi ...
# '\nfor sentence in captions_train_cleaned_stemmed_and_lemmatized_by_spacy:\n    print(sentence)\n    for token in sentence:\n        print(token,token.lemma_)'
